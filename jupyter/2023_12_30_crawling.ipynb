# %% [markdown]
# # Libraries

# %%
import pandas as pd

import requests
from bs4 import BeautifulSoup
from alpha_vantage.timeseries import TimeSeries
import yfinance as yf

from tqdm import tqdm

# %% [markdown]
# # Helpers

# %%
def crawl_top30_components_of_nifty50():
    response = requests.get('https://finance.yahoo.com/quote/%5ENSEI/components?p=%5ENSEI', headers={'user-agent': 'Mozilla 5.0'}).text
    bs4 = BeautifulSoup(response, 'lxml')
    bs4.select('section > div > table')[0].select('tr')[0].select('th')

    components = []
    for i, row in enumerate(bs4.select('section > div > table')[0].select('tr')):
        if i == 0:
            headers = [component.text for component in row.select('th')]
        else:
            components.append([component.text for component in row.select('td')])
    
    data = pd.DataFrame(components, columns=headers)
    
    return data

# %% [markdown]
# # Crawling

# %% [markdown]
# ## Components of NSEI

# %%
symbols = crawl_top30_components_of_nifty50()

# %%
symbols
# Out:
#            Symbol                             Company Name Last Price  Change  \
# 0   ULTRACEMCO.NS                 UltraTech Cement Limited  10,016.05    1.25
# 1       MARUTI.NS              Maruti Suzuki India Limited  10,017.00    1.70
# 2        TECHM.NS                    Tech Mahindra Limited   1,248.30    0.80
# 3   BAJFINANCE.NS                    Bajaj Finance Limited   7,711.15    5.60
# 4   BHARTIARTL.NS                    Bharti Airtel Limited   1,046.60   -1.30
# 5    COALINDIA.NS                       Coal India Limited     384.25   -0.50
# 6   APOLLOHOSP.NS      Apollo Hospitals Enterprise Limited   5,754.25   -7.95
# 7     HDFCLIFE.NS      HDFC Life Insurance Company Limited     646.75   -1.20
# 8        TITAN.NS                    Titan Company Limited   3,712.55   -7.15
# 9   TATACONSUM.NS           Tata Consumer Products Limited   1,122.95   -2.60
# 10    ADANIENT.NS                Adani Enterprises Limited   3,006.60    8.30
# 11  INDUSINDBK.NS                    IndusInd Bank Limited   1,643.20   -5.35
# 12    RELIANCE.NS              Reliance Industries Limited   2,607.70   11.05
# 13  BAJAJFINSV.NS                       Bajaj Finserv Ltd.   1,709.50    7.55
# 14   TATASTEEL.NS                       Tata Steel Limited     133.65   -0.60
# 15         ITC.NS                              ITC Limited     473.95   -2.45
# 16    HINDALCO.NS              Hindalco Industries Limited     587.00   -3.50
# 17        NTPC.NS                             NTPC Limited     314.95   -2.15
# 18       CIPLA.NS                            Cipla Limited   1,286.90   -9.75
# 19  BAJAJ-AUTO.NS                       Bajaj Auto Limited   6,978.50   56.35
# 20        ONGC.NS  Oil and Natural Gas Corporation Limited     216.45    1.80
# 21   KOTAKBANK.NS              Kotak Mahindra Bank Limited   1,847.60  -16.00
# 22       WIPRO.NS                            Wipro Limited     456.60    4.20
# 23  HEROMOTOCO.NS                    Hero MotoCorp Limited   3,990.30   43.35
# 24        LTIM.NS                      LTIMindtree Limited   5,947.65   81.25
# 25   BRITANNIA.NS             Britannia Industries Limited   5,272.35  -88.95
# 26   NESTLEIND.NS                     Nestlé India Limited   2,666.40  -45.25
# 27          LT.NS                  Larsen & Toubro Limited   3,521.90   63.20
# 28         TCS.NS        Tata Consultancy Services Limited   3,737.90   71.10
# 29          MM.NS                                    MM.NS
#
#    % Change      Volume
# 0    +0.01%     163,130
# 1    +0.02%     671,886
# 2    +0.06%   1,756,733
# 3    +0.07%   1,052,331
# 4    -0.12%   4,007,957
# 5    -0.13%   8,367,270
# 6    -0.14%     144,884
# 7    -0.19%   1,393,692
# 8    -0.19%     963,392
# 9    -0.23%   1,207,096
# 10   +0.28%   3,218,674
# 11   -0.32%   2,293,731
# 12   +0.43%   4,042,011
# 13   +0.44%     835,304
# 14   -0.45%  71,258,619
# 15   -0.51%   9,203,385
# 16   -0.59%   2,989,729
# 17   -0.68%  27,447,848
# 18   -0.75%   1,013,068
# 19   +0.81%     659,186
# 20   +0.84%  20,728,172
# 21   -0.86%   7,793,677
# 22   +0.93%   8,436,068
# 23   +1.10%     592,946
# 24   +1.39%     429,225
# 25   -1.66%     298,994
# 26   -1.67%   2,576,361
# 27   +1.83%   2,068,704
# 28   +1.94%   1,961,904
# 29

# %% [markdown]
# ## data

# %%
data = []
for symbol in tqdm(symbols.Symbol):
    data.append(yf.Ticker(symbol).history(start='1990-01-01').assign(symbol=symbol))

data = pd.concat(data)
# Out:
#  97%|█████████▋| 29/30 [00:16<00:00,  1.82it/s]MM.NS: No timezone found, symbol may be delisted
# 100%|██████████| 30/30 [00:16<00:00,  1.84it/s]

# %%
data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2002-08-12 00:00:00+05:30   281.341091   284.926805   280.881383   284.191284
# 2002-08-13 00:00:00+05:30   278.169098   287.777000   278.169098   285.846222
# 2002-08-14 00:00:00+05:30   278.674771   286.857561   278.674771   286.122040
# 2002-08-15 00:00:00+05:30   286.122040   286.122040   286.122040   286.122040
# 2002-08-16 00:00:00+05:30   285.018756   286.857587   283.225885   285.984131
# ...                                ...          ...          ...          ...
# 2024-01-01 00:00:00+05:30  3790.000000  3832.000000  3773.000000  3811.100098
# 2024-01-02 00:00:00+05:30  3811.100098  3811.100098  3767.250000  3783.199951
# 2024-01-03 00:00:00+05:30  3767.000000  3771.850098  3687.050049  3691.750000
# 2024-01-04 00:00:00+05:30  3701.750000  3719.000000  3651.000000  3666.800049
# 2024-01-05 00:00:00+05:30  3675.000000  3747.750000  3674.850098  3737.899902
#
#                               Volume  Dividends  Stock Splits         symbol  \
# Date
# 2002-08-12 00:00:00+05:30    13300.0        0.0           0.0  ULTRACEMCO.NS
# 2002-08-13 00:00:00+05:30    14200.0        0.0           0.0  ULTRACEMCO.NS
# 2002-08-14 00:00:00+05:30    40000.0        0.0           0.0  ULTRACEMCO.NS
# 2002-08-15 00:00:00+05:30        0.0        0.0           0.0  ULTRACEMCO.NS
# 2002-08-16 00:00:00+05:30    30600.0        0.0           0.0  ULTRACEMCO.NS
# ...                              ...        ...           ...            ...
# 2024-01-01 00:00:00+05:30   825907.0        0.0           0.0         TCS.NS
# 2024-01-02 00:00:00+05:30  1344068.0        0.0           0.0         TCS.NS
# 2024-01-03 00:00:00+05:30  1803075.0        0.0           0.0         TCS.NS
# 2024-01-04 00:00:00+05:30  3598144.0        0.0           0.0         TCS.NS
# 2024-01-05 00:00:00+05:30  1963127.0        0.0           0.0         TCS.NS
#
#                            Adj Close
# Date
# 2002-08-12 00:00:00+05:30        NaN
# 2002-08-13 00:00:00+05:30        NaN
# 2002-08-14 00:00:00+05:30        NaN
# 2002-08-15 00:00:00+05:30        NaN
# 2002-08-16 00:00:00+05:30        NaN
# ...                              ...
# 2024-01-01 00:00:00+05:30        NaN
# 2024-01-02 00:00:00+05:30        NaN
# 2024-01-03 00:00:00+05:30        NaN
# 2024-01-04 00:00:00+05:30        NaN
# 2024-01-05 00:00:00+05:30        NaN
#
# [160726 rows x 9 columns]

# %% [markdown]
# ## Save

# %%
data.to_pickle('../data/data.pickle')
